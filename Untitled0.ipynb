# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardayumi/PA-1C-grupo-A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nome = ("Eduarda") # variável tipo str (string)
Idade = 15 # variável # tipo número inteiro
Altura = 1,54 # variável tipo float
