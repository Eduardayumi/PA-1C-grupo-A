# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardayumi/PA-1C-grupo-A/blob/main/30_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que faz a 04 operações aritimética (calculadora simples)

print ("|-----Calculadora Simples-----|")
print ("")
print ("|-----------MENU--------------|")
print ("|                             |")
print ("| Soma = 1                    |")
print ("|                             |")
print ("| Subtração = 2               |")
print ("|                             |")
print ("| Multiplicação = 3           |")
print ("|                             |")
print ("| Divisão = 4                 |")
print ("|-----------------------------|")

a = int (input ("digite o primeiro número: "))
b = int (input ("digite o segundo número: "))
cu =int (input ("digite o número da ação desejada "))


if cu == 1:
 print (f"A soma é {a + b}")

elif cu == 2:
 print (f"A subtração é {a - b}")

elif cu == 3:
 print (f"A multiplicação é {a * b}")

else:
 print (f"A divisão é {a / b}")
# Out:
# |-----Calculadora Simples-----|
#
# |-----------MENU--------------|
# |                             |
# | Soma = 1                    |
# |                             |
# | Subtração = 2               |
# |                             |
# | Multiplicação = 3           |
# |                             |
# | Divisão = 4                 |
# |-----------------------------|
# digite o primeiro número: 5
# digite o segundo número: 5
# digite o número da ação desejada 3
# A multiplicação é 25

# %%
# Escrever um programa que o usuario digita a idade e retorna se é adolescente, criança ou adulto

# Entrada

Nome = str (input("Digite seu nome: "))
Idade = int (input("Digite sua idade: "))

# Processamento e saida

if Idade < 12:
 print (f"{Nome}, você é criança")
elif Idade < 18:
 print (f"{Nome}, você é adolescente")
else:
 print (f"{Nome}, você é adulto")
# Out:
# Digite seu nome: Eduarda
# Digite sua idade: 13
# Eduarda, você é adolescente

# %%
# Escreva um programa que classifica os triangulos

# Verificar se forma um trinagulo valido

# TIpo

# isosceles:
# Equilatero
# escaleno:

print ("|-----Verificação de um triângulo é válido-----|")
print ("")

a = int (input ("digite o primeiro valor do lado: "))
b = int (input ("digite o segundo valor do lado: "))
c = int (input ("digite o terceiro valor do lado: "))

# Processamento

print ("")

if a + b > c and a + c > b and b + c > a:
 print (f"É um triângulo válido")
 sys.exit()

else:
  print (f"Não é válido")

print ("")
print ("|-----Classificação quanto aos lado do triângulo-----|")
print ("")

if a == b != c:
   print (f"É um triângulo isosceles, pois possui pelo menos dois lados com a mesma medida  ")

elif a == b == c:
   print (f"É um triângulo equilatero, pois todos os três lados possuem a mesma medida")

else:

 print (f"É um triângulo escaleno, pois todos os três lados possuem medidas diferentes")
# Out:
# |-----Verificação de um triângulo é válido-----|
#
# digite o primeiro valor do lado: 42
# digite o segundo valor do lado: 535
# digite o terceiro valor do lado: 6746
#
# Não é válido
#
# |-----Classificação quanto aos lado do triângulo-----|
#
# É um triângulo escaleno, pois todos os três lados possuem medidas diferentes
