# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardayumi/PA-1C-grupo-A/blob/main/25_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = ""

while senha != 1234:

  senha = int (input("Digite sua senha: "))
# Out:
# Digite sua senha: 2444
# Digite sua senha: 5
# Digite sua senha: 1234

# %%
contador = 0

while contador <= 5:
  print (contador)
  contador +=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
contador = 5

while contador >= 0:
  print (contador)
  contador -=1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# Calculadora Simples - Escrever um programa que calcula as 04 operações matemáticas
#1- Somar 2-Subtrair 3-Multiplicar 4-dividir 5-sair

opcao = ""
a= 0
b= 0

print ("----------MENU----------")
print (" ")

print ("Opção 1 - Somar")
print ("Opção 2 - Subtrair")
print ("Opção 3 - Multiplicar")
print ("Opção 4 - Dividir")
print ("Opção 5 - Sair")

print ("-------------------------")
print (" ")

try:

  while opcao != 5:
    opcao = int (input("Digite a opção desejada ou 5 para sair: "))
    if opcao == 1:
      a = float (input("Digite o primeiro número: "))
      b = float (input("Digite o segundo número: "))
      print(f"Total da soma de {a} + {b} é igual: {a + b} ")
    elif opcao ==2:
      a = float (input("Digite o primeiro número: "))
      b = float (input("Digite o segundo número: "))
      print (f"Total da subtração de {a} - {b} é igual: {a - b}")
    elif opcao == 3:
      a = float (input("Digite o primeiro número: "))
      b = float (input("Digite o segundo número: "))
      print (f"Total da multiplicação de {a} x {b} é igual: {a * b}")
    elif opcao == 4:
      a= float (input("Digite o primeiro número: "))
      b = float (input("Digite o segundo número: "))
      print (f"Total da divisão de {a} / {b} é igual: {a / b}")
    elif opcao > 5:
      print (f"Opção não localizada, digite novamente")


      print (" ")

except:
  print("Digite apenas números de 01 a 05")
# Out:
# ----------MENU----------
#
# Opção 1 - Somar
# Opção 2 - Subtrair
# Opção 3 - Multiplicar
# Opção 4 - Dividir
# Opção 5 - Sair
# -------------------------
#
# Digite a opção desejada ou 5 para sair: 4
# Digite o primeiro número: 100
# Digite o segundo número: 30
# Total da divisão de 100.0 / 30.0 é igual: 3.3333333333333335
# Digite a opção desejada ou 5 para sair: 3
# Digite o primeiro número: 5
# Digite o segundo número: 5
# Total da multiplicação de 5.0 x 5.0 é igual: 25.0
# Digite a opção desejada ou 5 para sair: 5

# %%
nuhuh = 1

media = (nota_1 + nota_2 + nota_3 + nota_4) / 4

while nuhuh == 1:
  nota_1 = float (input("Digite a primeira nota: "))
  nota_2 = float (input("Digite a segunda nota: "))
  nota_3 = float (input("Digite a terceira nota: "))
  nota_4 = float (input("Digite a quarta nota: "))
  if nuhuh <= 10:
    print (f"Média é igual a {media}, foi aprovado!")
  elif nuhuh >= 7.0:
    print (f"Média é igual a {media}, está de recuperação!")
  else:
    print (f"Média é igual a {media}, foi reprovado!")
# Out:
# Digite a primeira nota: 10
# Digite a segunda nota: 10
# Digite a terceira nota: 10
# Digite a quarta nota: 10
# Média é igual a 10.0, foi aprovado!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6612/3311412148.py in <cell line: 0>()
#       4
#       5 while nuhuh == 1:
# ----> 6   nota_1 = float (input("Digite a primeira nota: "))
#       7   nota_2 = float (input("Digite a segunda nota: "))
#       8   nota_3 = float (input("Digite a terceira nota: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
continuar = 1 # Variável para controlar o loop

while continuar == 1:
    nota_1 = float(input("Digite a primeira nota: "))
    nota_2 = float(input("Digite a segunda nota: "))
    nota_3 = float(input("Digite a terceira nota: "))
    nota_4 = float(input("Digite a quarta nota: "))

    # As notas são calculadas DEPOIS de serem digitadas
    media = (nota_1 + nota_2 + nota_3 + nota_4) / 4

    # Verificação baseada na 'media' calculada
    if media >= 7.0:
        print(f"Média é igual a {media:.2f}, foi aprovado!\n")
    elif media >= 5.0: # Exemplo de nota para recuperação
        print(f"Média é igual a {media:.2f}, está de recuperação!\n")
    else:
        print(f"Média é igual a {media:.2f}, foi reprovado!\n")

    # Pergunta se o usuário deseja continuar ou parar
# Out:
# Digite a primeira nota: 10
# Digite a segunda nota: 10
# Digite a terceira nota: 0
# Digite a quarta nota: 10
# Média é igual a 7.50, foi aprovado!
#
# Digite 1 para continuar ou 4 para sair: 2

# %%
# Escrava um programa que recebe 04 notas, calcula a média e indica se o aluno foi aprovado, reprovado ou está de recuperação
# Maior que 07 - aprovado
# Maior ou igual a 05 - recuperação
# Menor que 05 reprovado

nota_1 = float (input("Digite a primeira nota: "))
nota_2 = float (input("Digite a segunda nota: "))
nota_3 = float (input("Digite a terceira nota: "))
nota_4 = float (input("Digite a quarta nota: "))

media = (nota_1 + nota_2 + nota_3 + nota_4) / 4
na = (nota_1, nota_2, nota_3, nota_4)

print (" ")

if media == 10:
  print (f"Média é igual a {media}, foi aprovado!")
elif media <= 7:
  print (f"Média é igual a {media}, está de recuperação!")
elif media >= 11:
  print (f"Notas inválidas")
else:
  print (f"Média é igual a {media}, foi reprovado!")
# Out:
# Digite a primeira nota: 534
# Digite a segunda nota: 543
# Digite a terceira nota: 534
# Digite a quarta nota: 53
#
# Notas inválidas
