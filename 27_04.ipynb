# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardayumi/PA-1C-grupo-A/blob/main/27_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#interações e laços de repetição

for i in range (5):
  print ("olá mundo")
# Out:
# olá mundo
# olá mundo
# olá mundo
# olá mundo
# olá mundo

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (1, 6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Escrever um programa que imprime de 5 até 0



for i in range (7):
  print (6-i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# escrever um programa que imprime os números pares de 0 a 10

for i in range (6):
  print (i * 2)


print("  -   ")


for i in range (11):

  if i % 2 == 0:
    print (i)


print("   -  ")


for i in range (0, 11, 2):
  print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
#   -
# 0
# 2
# 4
# 6
# 8
# 10
#    -
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#imprim números impares

for i in range (1, 11, 2):
 print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# Escrever um programa que o usuário digita um número de 1 a 10 e imprime a tabuada

numero = int (input("Digite um número de 1 a 10: "))

for i in range (11):

  if numero >= 1 and numero <= 10:
   print (f" {numero} x {i} = {i* numero}")
# Out:
# Digite um número de 1 a 10: 9
#  9 x 0 = 0
#  9 x 1 = 9
#  9 x 2 = 18
#  9 x 3 = 27
#  9 x 4 = 36
#  9 x 5 = 45
#  9 x 6 = 54
#  9 x 7 = 63
#  9 x 8 = 72
#  9 x 9 = 81
#  9 x 10 = 90
