# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardayumi/PA-1C-grupo-A/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calcular a área do retângulo

# entrada

Comprimento = float (input("digite o comprimento "))
Altura = float (input("digite o valor da altura "))

#Processamento

area = Comprimento * Altura

#Saida

print ("-----ÁREA DO RETÂNGULO-----")
print ("")
print (f"A área total do retângulo é igual: {area}")
# Out:
# digite o comprimento 3
# digite o valor da altura 3
# -----ÁREA DO RETÂNGULO-----
#
# A área total do retângulo é igual: 9.0

# %%
# Fazer um cadastro simples, com nome do usuário e a idade
#Entrada: nome e idade

#Processamento : armazenar dados

# Saida : Mensagem de boas vindas

# Entrada

nome = str (input ("digite seu nome: "))
idade = int (input("digite sua idade: "))

# Saída

print (f"Olá, {nome} , seja bem vindo ")
print (f"Você tem {idade} anos .")
# Out:
# digite seu nome: Eduarda
# digite sua idade: 13
# Olá, Eduarda , seja bem vindo
# Você tem 13 anos .
